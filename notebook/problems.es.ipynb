# %% [markdown]
# # Ejercicios de probabilidad

# %% [markdown]
# ## Ejercicio 1
#
# Dos dados se lanzan una vez y se observa el total obtenido. Usa una simulación para encontrar la probabilidad estimada de que la puntuación sea mayor a 7 o un número par. Una simulación es una repetición del mismo experimento multiples veces para observar su comportamiento:
#
# - Ejecuta el experimento 1000 veces (lanza 2 dados 1000 veces, y suma el número de ambos dados).
# - Lleva ua cuenta de los números y las veces que la suma fue mayor a 7 o un número par.
# - Divide el número del paso 2 entre el número de iteraciones(1000).

# %%
# TODO
import random

def lanzar_dado():
    dado1 = random.randint(1,6)
    dado2 = random.randint(1,6)
    return dado1,dado2

def experimentar(n):
    suma = 0
    contador = 0
    for i in range(0,n):
        lanzamiento = lanzar_dado()
        suma += lanzamiento[0]+lanzamiento[1]
        if (lanzamiento[0]+lanzamiento[1])%2==0 or (lanzamiento[0]+lanzamiento[1])>7:
            contador += 1
    return suma,contador

suma_1000_experimentos ,contador = experimentar(1000)

print(f"La suma de los lados es : {suma_1000_experimentos}\n\
      Veces que el resultado de la suma de ambos lados fue mayor de 7 o par: {contador} veces.")

print(contador/2)
# Out:
# La suma de los lados es : 7067
# Veces que el resultado de la suma de ambos lados fue mayor de 7 o par: 673 veces.
# 336.5

# %% [markdown]
# ## Ejercicio 2
#
# Una caja contiene 10 bolas blancas, 20 bolas rojas y 30 bolas verdes. Si tomamos 5 bolas de la caja reemplazándolas (tomando una bola, anotando el color y luego regresandola a la caja). Queremos saber la probabilidad de:
#
# 1. Tomar 3 blancas y 2 rojas.
# 2. Toas todas del mismo color.
#
# Ejecuta el experimento 1000 veces y calcula las probabilidades que mencionadas.

# %%
ball_box = {}

# Crea la cajas con las bolas
for i in range(60):
    if i < 10:
        ball_box[i] = "White"
    elif (i > 9) and (i < 30):
        ball_box[i] = "Red"
    else:
        ball_box[i] = "Green"

#print(ball_box)
            
# TODO

def tomar_bolas(n):
    caso_1 = 0 # Tomar 3 blancas y dos rojas
    caso_2 = 0 # Tomar todas del mismo color
    for i in range(0,n):    
        bolas = [random.randint(0,59) for i in range(5)]
        blancas = 0
        rojas = 0
        verdes = 0
        for bola in bolas:
            if bola < 10:
                blancas +=1
            elif bola > 9 and bola < 30:
                rojas +=1
            else:
                verdes +=1        
        if blancas == 5 or rojas == 5 or verdes == 5:
            caso_2 += 1
        elif blancas == 3 and rojas ==2:
            caso_1 += 1
    
    return caso_1, caso_2

caso_1, caso_2 = tomar_bolas(1000)

print(f"En 1000 experimentos sacando 5 bolas hemos obtenido lo siguiente:\n\
Han salido todas las bolas del mismo color {caso_2} veces\n\
Han salido 3 bolas blancas y 2 bolas rojas {caso_1} veces" )

print(f"La probabilidad de que al sacar 5 bolas sean todas del mismo color es de un {round(((caso_2/1000)*100),2)} %, segun los resultados")
print(f"La probabilidad de que al sacar 5 bolas sean 3 blancas y 2 rojas de un {round(((caso_1/1000)*100),2)} %, segun los resultados")
# Out:
# En 1000 experimentos sacando 5 bolas hemos obtenido lo siguiente:
# Han salido todas las bolas del mismo color 39 veces
# Han salido 3 bolas blancas y 2 bolas rojas 3 veces
# La probabilidad de que al sacar 5 bolas sean todas del mismo color es de un 3.9 %, segun los resultados
# La probabilidad de que al sacar 5 bolas sean 3 blancas y 2 rojas de un 0.3 %, segun los resultados
